# %%
import matplotlib.pyplot as plt
import numpy as np

from astropy.visualization import astropy_mpl_style

plt.style.use(astropy_mpl_style)

from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename

cartwheel = fits.open(r"C:\Users\Abhim\Desktop\MAST_2023-06-13T0527\MAST_2023-06-13T0527\JWST\jw02727-o002_t062_nircam_clear-f090w\jw02727-o002_t062_nircam_clear-f090w_i2d.fits")

# %%
cartwheel
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x00000213D4E4A7A0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB74C0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB7760>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB79A0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB7B50>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB7730>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB7C70>, <astropy.io.fits.hdu.image.ImageHDU object at 0x00000213D4EB7EB0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x00000213D4EF8130>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x00000213D4EF81F0>]

# %%
cartwheel[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2023-04-01T12:23:45.412' / UTC date file created
# ORIGIN  = 'STSCI   '           / Organization responsible for creating file
# TIMESYS = 'UTC     '           / principal time system for time-related keywords
# TIMEUNIT= 's       '           / Default unit applicable to all time values
# FILENAME= 'jw02727-o002_t062_nircam_clear-f090w_i2d.fits' / Name of the file
# SDP_VER = '2022_5c '           / Data processing software version number
# PRD_VER = 'PRDOPSSOC-060'      / S&OC PRD version number used in data processing
# OSS_VER = '8.4.8   '           / Observatory Scheduling Software (OSS) version n
# CAL_VER = '1.9.6   '           / Calibration software version number
# CAL_VCS = 'RELEASE '           / Calibration software version control sys number
# ...

# %%
cartwheel[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4648
# NAXIS2  =                 4637
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# MJD-BEG =    59742.13109312025 / [d] exposure start time in MJD
# MJD-AVG =    59742.15054160787 / [d] exposure mid-point in MJD
# MJD-END =    59742.16998949074 / [d] exposure end time in MJD
# TDB-BEG =    59742.13104009056 / [d] TDB time of exposure start in MJD
# TDB-MID =    59742.15048727891 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59742.16993386261 / [d] TDB time of exposure end in MJD
# XPOSURE =            10994.464 / [s] Effective exposure time
# TELAPSE =            10994.464 / [s] Total elapsed exposure time
#
#         JWST ephemeris information
#
# ...

# %%
cartwheel.info()
# Out:
# Filename: C:\Users\Abhim\Desktop\MAST_2023-06-13T0527\MAST_2023-06-13T0527\JWST\jw02727-o002_t062_nircam_clear-f090w\jw02727-o002_t062_nircam_clear-f090w_i2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     374   ()
#   1  SCI           1 ImageHDU        74   (4648, 4637)   float32
#   2  ERR           1 ImageHDU        10   (4648, 4637)   float32
#   3  CON           1 ImageHDU        10   (4648, 4637, 1)   int32
#   4  WHT           1 ImageHDU         9   (4648, 4637)   float32
#   5  VAR_POISSON    1 ImageHDU         9   (4648, 4637)   float32
#   6  VAR_RNOISE    1 ImageHDU         9   (4648, 4637)   float32
#   7  VAR_FLAT      1 ImageHDU         9   (4648, 4637)   float32
# ...

# %%
data = cartwheel[1].data
type (data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (4637, 4648)

# %%
data.dtype.name
# Out:
# 'float32'

# %%
print ('Min', np.min(data))
print ('Max', np.max(data))
print ('Mean', np.mean(data))
print ('SD', np.std(data))
# Out:
# Min -0.15660453
# Max 656.4112
# Mean 0.26768228
# SD 0.8018397

# %%
plt.imshow (data, cmap = "gray")
plt.colorbar()

# %%
from matplotlib.colors import SymLogNorm

plt.imshow(data, cmap='gray', norm=SymLogNorm(1))
cbar = plt.colorbar(ticks=[1.e3,5.e3,1.e4])
cbar.ax.set_yticklabels(['1,000','5,000','10,000'])
# Out:
# [Text(1, 1000.0, '1,000'),
#  Text(1, 5000.0, '5,000'),
#  Text(1, 10000.0, '10,000')]

# %%
from astropy.visualization import make_lupton_rgb

r = fits.open (r"C:\Users\Abhim\Desktop\MAST_2023-06-13T0604\JWST\jw02727-o002_t062_nircam_clear-f356w\jw02727-o002_t062_nircam_clear-f356w_i2d.fits")[1].data
g = fits.open (r"C:\Users\Abhim\Desktop\MAST_2023-06-13T0541\JWST\jw02727-o002_t062_nircam_clear-f277w\jw02727-o002_t062_nircam_clear-f277w_i2d.fits")[1].data
b = fits.open (r"C:\Users\Abhim\Desktop\MAST_2023-06-24T0641\JWST\jw02727-o002_t062_nircam_clear-f444w\jw02727-o002_t062_nircam_clear-f444w_i2d.fits")[1].data

print(r.shape)
print(g.shape)
print(b.shape)

print(r.shape)
print(g.shape)
print(b.shape)
# Out:
# (2265, 2269)
# (2265, 2269)
# (2265, 2269)
# (2265, 2269)
# (2265, 2269)
# (2265, 2269)

# %%
import cv2
rgb_default = make_lupton_rgb(r*(35),g*(14),b*(14.2),stretch=1400,Q=50)
final = cv2.convertScaleAbs(rgb_default, 100, 20)

plt.grid(False)
plt.imshow(final)

plt.savefig('cartwheel.png')
